# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %% [markdown]
# BASIC GRAPHS

# %%
#line graph
x= [1,2,3]
y=[2,4,6]
plt.plot(x,y, label ='2x')
#if you want to add a legend you fist have to add a label 
plt.legend()
plt.show()

# %%
x2= np.arange(0, 4.5, 0.5)
plt.plot(x2, x2 **2,'r*--', label='exponent')
